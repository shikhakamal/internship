# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_excel(r'C:\Users\Hp\Desktop\data trained\internshp\Fake-News-Project--1-\Fake News Project\Fake.xlsx')
df1
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Yearâ...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obamaâ€™s Na...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23518  McPain: John McCain Furious That Iran Treated ...
# 23519  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23520  Sunnistan: US and Allied â€˜Safe Zoneâ€™ Plan ...
# 23521  How to Blow $700 Million: Al Jazeera America F...
# 23522  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
df2=pd.read_excel(r'C:\Users\Hp\Desktop\data trained\internshp\Fake-News-Project--1-\Fake News Project\True.xlsx')
df2
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
df1['target']='fake'
df2['target']='true'

# %%
df=pd.concat([df1, df2]).reset_index(drop=True)

# %%
df
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Yearâ...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obamaâ€™s Na...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44935  'Fully committed' NATO backs new U.S. approach...
# 44936  LexisNexis withdrew two products from Chinese ...
# 44937  Minsk cultural hub becomes haven from authorities
# 44938  Vatican upbeat on possibility of Pope Francis ...
# 44939  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
from sklearn.utils import shuffle
df=shuffle(df)
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                    title  \
# 0       What Trump Just Said The GOP Will Become If H...
# 1      Japanese PM Abe sends ritual offering to Yasuk...
# 2      [VIDEO] â€œUNBIASEDâ€ OREGON RANCHER AND WIFE...
# 3       Obama Probing Putin: Orders Review Of Russian...
# 4       Trump Ignores Constitution, Suggests INSANE P...
# ...                                                  ...
# 44935  FACTBOX: Oil companies in Caribbean, southeast...
# 44936  Prominent U.S. religious conservatives defend ...
# 44937   Trump Is ACTIVELY Working To RIP Families Awa...
# 44938  Kremlin: U.S. to blame for no Putin-Trump bila...
# 44939  OBAMA FIGHTS TO KEEP RADICAL AGENDA ALIVE: Ask...
#
#                                                     text          subject  \
# 0      How does the saying go? If we don t learn from...             News
# 1      TOKYO (Reuters) - Japanese Prime Minister Shin...        worldnews
# ...

# %%
df.drop(df.columns[4 : 171], axis=1, inplace=True)

# %%
df
# Out:
#                                                    title  \
# 0       What Trump Just Said The GOP Will Become If H...
# 1      Japanese PM Abe sends ritual offering to Yasuk...
# 2      [VIDEO] â€œUNBIASEDâ€ OREGON RANCHER AND WIFE...
# 3       Obama Probing Putin: Orders Review Of Russian...
# 4       Trump Ignores Constitution, Suggests INSANE P...
# ...                                                  ...
# 44935  FACTBOX: Oil companies in Caribbean, southeast...
# 44936  Prominent U.S. religious conservatives defend ...
# 44937   Trump Is ACTIVELY Working To RIP Families Awa...
# 44938  Kremlin: U.S. to blame for no Putin-Trump bila...
# 44939  OBAMA FIGHTS TO KEEP RADICAL AGENDA ALIVE: Ask...
#
#                                                     text          subject  \
# 0      How does the saying go? If we don t learn from...             News
# 1      TOKYO (Reuters) - Japanese Prime Minister Shin...        worldnews
# ...

# %% [markdown]
# we can delete the date as it is not required for any modelling calculations and assumptions.

# %%
df.drop(['Unnamed: 171'], axis=1, inplace=True)

# %%
df.drop(['date'], axis=1, inplace=True)

# %%
df
# Out:
#                                                    title  \
# 0       What Trump Just Said The GOP Will Become If H...
# 1      Japanese PM Abe sends ritual offering to Yasuk...
# 2      [VIDEO] â€œUNBIASEDâ€ OREGON RANCHER AND WIFE...
# 3       Obama Probing Putin: Orders Review Of Russian...
# 4       Trump Ignores Constitution, Suggests INSANE P...
# ...                                                  ...
# 44935  FACTBOX: Oil companies in Caribbean, southeast...
# 44936  Prominent U.S. religious conservatives defend ...
# 44937   Trump Is ACTIVELY Working To RIP Families Awa...
# 44938  Kremlin: U.S. to blame for no Putin-Trump bila...
# 44939  OBAMA FIGHTS TO KEEP RADICAL AGENDA ALIVE: Ask...
#
#                                                     text          subject  \
# 0      How does the saying go? If we don t learn from...             News
# 1      TOKYO (Reuters) - Japanese Prime Minister Shin...        worldnews
# ...

# %%
df.head()
# Out:
#                                                title  \
# 0   What Trump Just Said The GOP Will Become If H...
# 1  Japanese PM Abe sends ritual offering to Yasuk...
# 2  [VIDEO] â€œUNBIASEDâ€ OREGON RANCHER AND WIFE...
# 3   Obama Probing Putin: Orders Review Of Russian...
# 4   Trump Ignores Constitution, Suggests INSANE P...
#
#                                                 text          subject target
# 0  How does the saying go? If we don t learn from...             News   fake
# 1  TOKYO (Reuters) - Japanese Prime Minister Shin...        worldnews   true
# 2   I ve never had anybody point a gun at me befo...  Government News   fake
# 3  President Obama has ordered a  full review  of...             News   fake
# 4  Donald Trump has been going off on his infamou...             News   fake

# %%
df.tail()
# Out:
#                                                    title  \
# 44935  FACTBOX: Oil companies in Caribbean, southeast...
# 44936  Prominent U.S. religious conservatives defend ...
# 44937   Trump Is ACTIVELY Working To RIP Families Awa...
# 44938  Kremlin: U.S. to blame for no Putin-Trump bila...
# 44939  OBAMA FIGHTS TO KEEP RADICAL AGENDA ALIVE: Ask...
#
#                                                     text          subject  \
# 44935  (Reuters) - Energy infrastructure companies in...        worldnews
# 44936  WASHINGTON (Reuters) - Two prominent religious...     politicsNews
# 44937  A letter to the editor appeared in The New Yor...             News
# 44938  MOSCOW (Reuters) - The Kremlin said on Sunday ...        worldnews
# 44939  This is a good reminder of how important it is...  Government News
#
#       target
# 44935   true
# 44936   true
# 44937   fake
# 44938   true
# 44939   fake

# %%
df.shape
# Out:
# (44940, 4)

# %%
df.sample()
# Out:
#                                                    title  \
# 10361  U.N. says missiles fired at Saudi Arabia have ...
#
#                                                     text    subject target
# 10361  UNITED NATIONS (Reuters) - United Nations offi...  worldnews   true

# %%
df.isnull().sum()
# Out:
# title      21
# text       21
# subject    42
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44940 entries, 0 to 44939
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44919 non-null  object
#  1   text     44919 non-null  object
#  2   subject  44898 non-null  object
#  3   target   44940 non-null  object
# dtypes: object(4)
# memory usage: 1.4+ MB

# %%
df.columns
# Out:
# Index(['title', 'text', 'subject', 'target'], dtype='object')

# %%
df.describe()
# Out:
#                                                     title   text  \
# count                                               44919  44919
# unique                                              38740  38657
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14    627
#
#              subject target
# count          44898  44940
# unique            19      2
# top     politicsNews   fake
# freq           11272  23523

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df_corr=df.corr()
df_corr
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.dtypes
# Out:
# title      object
# text       object
# subject    object
# target     object
# dtype: object

# %%
sns.countplot(df['target'])
df['target'].value_counts()
# Out:
# fake    23523
# true    21417
# Name: target, dtype: int64

# %%
sns.countplot(df['subject'])
df['subject'].value_counts()
# Out:
# politicsNews                                                                                                                                                                                                                                                                                    11272
# worldnews                                                                                                                                                                                                                                                                                       10145
# News                                                                                                                                                                                                                                                                                             9050
# ...

# %%
df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# target     0
# dtype: int64

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#        title   text  subject  target
# 0       8659  13644       13       0
# 1      20889  26121       18       1
# 2      38480    389       11       0
# 3       4081  23040       13       0
# 4       6547  10132       13       0
# ...      ...    ...      ...     ...
# 44935  16123   1197       18       1
# 44936  26275  34594       17       1
# 44937   6568   3079       13       0
# 44938  21420  19257       18       1
# 44939  24419  28428       11       0
#
# [44940 rows x 4 columns]

# %%
df.dtypes
# Out:
# title      int32
# text       int32
# subject    int32
# target     int32
# dtype: object

# %%
plt.boxplot(df['title'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9a06f7430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f9a06f7a90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9a06f7160>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f9a06f7f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f9a0c81280>],
#  'means': []}

# %%
plt.boxplot(df['text'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9a0cb98e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f9a0cb9e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9a0cb9730>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f9a0709460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f9a0709730>],
#  'means': []}

# %%
plt.boxplot(df['subject'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f9a07683d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f9a0768970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f9a0768220>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f9a0768f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f9a0775220>],
#  'means': []}

# %% [markdown]
# REMOVING OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#           title      text   subject    target
# 0      1.018358  0.460786  1.315761  0.954186
# 1      0.092367  0.639634  1.103764  1.048014
# 2      1.689976  1.629822  2.283571  0.954186
# 3      1.434130  0.367902  1.315761  0.954186
# 4      1.210169  0.770530  1.315761  0.954186
# ...         ...       ...       ...       ...
# 44935  0.340480  1.558560  1.103764  1.048014
# 44936  0.581522  1.386917  0.619859  1.048014
# 44937  1.208262  1.392576  1.315761  0.954186
# 44938  0.140592  0.034257  1.103764  1.048014
# 44939  0.412960  0.843102  2.283571  0.954186
#
# [44940 rows x 4 columns]

# %%
print(np.where(z>3))
# Out:
# (array([ 2212,  4024,  5969,  6411,  7189,  7616,  8306, 16323, 22502,
#        24723, 25420, 29253, 30871, 31218, 33238, 34592, 38425, 42278,
#        44201], dtype=int64), array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
#       dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        title   text  subject  target
# 0       8659  13644       13       0
# 1      20889  26121       18       1
# 2      38480    389       11       0
# 3       4081  23040       13       0
# 4       6547  10132       13       0
# ...      ...    ...      ...     ...
# 44935  16123   1197       18       1
# 44936  26275  34594       17       1
# 44937   6568   3079       13       0
# 44938  21420  19257       18       1
# 44939  24419  28428       11       0
#
# [44921 rows x 4 columns]

# %%
df.shape
# Out:
# (44940, 4)

# %%
df_new.shape
# Out:
# (44921, 4)

# %% [markdown]
# CHECKING FOR SKEWNESS

# %%
sns.distplot(df['title'])
# Out:
# <AxesSubplot:xlabel='title', ylabel='Density'>

# %%
sns.distplot(df['text'])
# Out:
# <AxesSubplot:xlabel='text', ylabel='Density'>

# %%
sns.distplot(df['subject'])
# Out:
# <AxesSubplot:xlabel='subject', ylabel='Density'>

# %%
df_new.skew().sort_values(ascending=False)
# Out:
# target     0.093022
# text       0.016077
# title     -0.016030
# subject   -0.641127
# dtype: float64

# %%
x=df_new.drop('target', axis=1)
x
# Out:
#        title   text  subject
# 0       8659  13644       13
# 1      20889  26121       18
# 2      38480    389       11
# 3       4081  23040       13
# 4       6547  10132       13
# ...      ...    ...      ...
# 44935  16123   1197       18
# 44936  26275  34594       17
# 44937   6568   3079       13
# 44938  21420  19257       18
# 44939  24419  28428       11
#
# [44921 rows x 3 columns]

# %%
y=df_new['target']
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 44935    1
# 44936    1
# 44937    0
# 44938    1
# 44939    0
# Name: target, Length: 44921, dtype: int32

# %%
x.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
maxAcc=0
maxRS=0

for i in range(0,200):
    lr=LogisticRegression()
    x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=i)
    lr.fit(x_train, y_train)
    y_pred=lr.predict(x_test)
    score=accuracy_score(y_test, y_pred)
    print('score is ', score,' random state ',i)
    
    if score>maxAcc:
        maxAcc=score
        maxRS=i
        print('max score is ', maxAcc, ' at random state ',maxRS)
# Out:
# score is  0.6517529215358931  random state  0
# max score is  0.6517529215358931  at random state  0
# score is  0.6420701168614358  random state  1
# score is  0.6414023372287145  random state  2
# score is  0.6369504730105732  random state  3
# score is  0.6432943795214245  random state  4
# score is  0.6377295492487479  random state  5
# score is  0.6483027267668336  random state  6
# score is  0.6435169727323317  random state  7
# score is  0.6483027267668336  random state  8
# score is  0.6434056761268782  random state  9
# score is  0.6487479131886478  random state  10
# score is  0.6503060656649973  random state  11
# score is  0.643183082915971  random state  12
# score is  0.6402893711741792  random state  13
# score is  0.6388425153032833  random state  14
# score is  0.6464106844741235  random state  15
# score is  0.6497495826377295  random state  16
# score is  0.642960489705064  random state  17
# score is  0.6342793544796884  random state  18
# ...

# %% [markdown]
# max score is 65.175% at random state 0

# %%
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.20, random_state=0)

# %%
lr=LogisticRegression()
dtc=DecisionTreeClassifier()
gnb=GaussianNB()
rfc=RandomForestClassifier()
knb=KNeighborsClassifier()

list=[lr, dtc, gnb, rfc, knb]
for i in list:
    print('\n\n The ',i, ' is :\n')
    i.fit(x_train, y_train)
    y_pred=i.predict(x_test)
    a=accuracy_score(y_test, y_pred)
    b=confusion_matrix(y_test, y_pred)
    c=classification_report(y_test, y_pred)
    
    print('accuracy score ',a)
    print('confusion matrix ',b)
    print('classification report \n',c)
# Out:
#  The  LogisticRegression()  is :
#
# accuracy score  0.6517529215358931
# confusion matrix  [[2723 1999]
#  [1130 3133]]
# classification report
#                precision    recall  f1-score   support
#
#            0       0.71      0.58      0.64      4722
#            1       0.61      0.73      0.67      4263
#
#     accuracy                           0.65      8985
#    macro avg       0.66      0.66      0.65      8985
# weighted avg       0.66      0.65      0.65      8985
#
#
#
#  The  DecisionTreeClassifier()  is :
#
# accuracy score  1.0
# confusion matrix  [[4722    0]
#  [   0 4263]]
# classification report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4722
#            1       1.00      1.00      1.00      4263
#
#     accuracy                           1.00      8985
#    macro avg       1.00      1.00      1.00      8985
# weighted avg       1.00      1.00      1.00      8985
#
#
#
# ...

# %% [markdown]
# CROSS VALIDATION SCORE

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in list:
    scr=cross_val_score(i, x, y, cv=5)
    print(' cross validation score of ', i, ' is ', scr.mean())
# Out:
#  cross validation score of  LogisticRegression()  is  0.6411700588345768
#  cross validation score of  DecisionTreeClassifier()  is  1.0
#  cross validation score of  GaussianNB()  is  0.9977293535133999
#  cross validation score of  RandomForestClassifier()  is  1.0
#  cross validation score of  KNeighborsClassifier()  is  0.9616883511700266

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
y_pred1=gnb.predict(x_test)

fpr, tpr,thresholds=roc_curve(y_test, y_pred1)
print('fpr is ',fpr)
print('tpr is ',tpr)
print('thresholds is ', thresholds)
# Out:
# fpr is  [0.         0.00444727 1.        ]
# tpr is  [0. 1. 1.]
# thresholds is  [2 1 0]

# %%
from sklearn import metrics

plt.plot([0,1], [0,1], 'k--')
plt.title('Gaussian NB curve')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.plot(fpr,tpr)
plt.show()

auc_score=roc_auc_score(y_test, y_pred)
print('roc auc score is ', auc_score)
# Out:
# roc auc score is  0.9656179871063353

# %% [markdown]
# HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'var_smoothing':np.logspace(0,-9,num=100)
    
}

# %%
gridsearch=GridSearchCV(gnb, 
                       parameters,
                       n_jobs=-1,
                       scoring='accuracy',
                       cv=5)

# %%
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GaussianNB(), n_jobs=-1,
#              param_grid={'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.51119173e-02, 2.8480358...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy')

# %%
gridsearch.best_params_
# Out:
# {'var_smoothing': 1e-09}

# %%
gnb=GaussianNB(var_smoothing=1e-09)
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9976627712854758

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[4701,   21],
#        [   0, 4263]], dtype=int64)

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      4722\n           1       1.00      1.00      1.00      4263\n\n    accuracy                           1.00      8985\n   macro avg       1.00      1.00      1.00      8985\nweighted avg       1.00      1.00      1.00      8985\n'

# %%
import joblib
joblib.dump(gnb.predict, 'fakenews.pkl')
# Out:
# ['fakenews.pkl']
