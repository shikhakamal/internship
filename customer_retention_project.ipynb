# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('customer_retention.csv', sep='\t')
data
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df=pd.DataFrame(data=data)
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.head(4)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
# 2                                  3-4 years
# 3                                  3-4 years
#
# ...

# %%
df.tail()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# ...

# %%
df.tail(3)
# Out:
#     1Gender of respondent 2 How old are you?   \
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#     5 Since How Long You are Shopping Online ?  \
# 266                                  2-3 years
# 267                                  2-3 years
# 268                                  2-3 years
#
#     6 How many times you have made an online purchase in the past 1 year?  \
# 266                                 Less than 10 times
# ...

# %%
df.sample()
# Out:
#     1Gender of respondent 2 How old are you?   \
# 127                Female         31-40 years
#
#     3 Which city do you shop online from?  \
# 127                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 127                                             201008
#
#     5 Since How Long You are Shopping Online ?  \
# 127                                  1-2 years
#
#     6 How many times you have made an online purchase in the past 1 year?  \
# 127                                        31-40 times
#
#     7 How do you access the internet while shopping on-line?  \
# 127                                    Mobile Internet
#
#     8 Which device do you use to access the online shopping?  \
# 127                                         Smartphone
#
#     9 What is the screen size of your mobile device?\t\t\t\t\t\t                                          \
# 127                                             Others
#
# ...

# %%
df.sample(2)
# Out:
#     1Gender of respondent 2 How old are you?   \
# 155                Female  51 years and above
# 182                Female         21-30 years
#
#     3 Which city do you shop online from?  \
# 155                              Gurgaon
# 182                                 Solan
#
#      4 What is the Pin Code of where you shop online from?  \
# 155                                             122009
# 182                                             173212
#
#     5 Since How Long You are Shopping Online ?  \
# 155                           Less than 1 year
# 182                                  1-2 years
#
#     6 How many times you have made an online purchase in the past 1 year?  \
# 155                                 Less than 10 times
# 182                                 Less than 10 times
#
#     7 How do you access the internet while shopping on-line?  \
# 155                                              Wi-Fi
# 182                                    Mobile Internet
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.shape
# Out:
# (269, 71)

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
df.describe(include='all')
# Out:
#        1Gender of respondent 2 How old are you?   \
# count                    269                 269
# unique                     2                   5
# top                   Female         31-40 years
# freq                     181                  81
# mean                     NaN                 NaN
# std                      NaN                 NaN
# min                      NaN                 NaN
# 25%                      NaN                 NaN
# 50%                      NaN                 NaN
# 75%                      NaN                 NaN
# max                      NaN                 NaN
#
#        3 Which city do you shop online from?  \
# count                                    269
# unique                                    11
# top                                    Delhi
# freq                                      58
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df_corr= df.corr()
df_corr
# Out:
#                                                     4 What is the Pin Code of where you shop online from?
# 4 What is the Pin Code of where you shop online...                                                1.0

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
data=pd.read_csv('customer_retention_codedatasets.csv', sep='\t')
data
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
data.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.describe(include='all')
# Out:
#         1Gender of respondent  2 How old are you?   \
# count              269.000000           269.000000
# unique                    NaN                  NaN
# top                       NaN                  NaN
# freq                      NaN                  NaN
# mean                 0.669145             2.959108
# std                  0.471398             1.066012
# min                  0.000000             1.000000
# 25%                  0.000000             2.000000
# 50%                  1.000000             3.000000
# 75%                  1.000000             4.000000
# max                  1.000000             5.000000
#
#        3 Which city do you shop online from?  \
# count                                    269
# unique                                    11
# top                                    Delhi
# freq                                      58
# mean                                     NaN
# std                                      NaN
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data.describe(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# VISUALIZATION

# %%
data.dtypes
# Out:
# 1Gender of respondent                                                    int64
# 2 How old are you?                                                       int64
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                               int64
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
data.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
sns.countplot(data['2 How old are you? '])
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %% [markdown]
# majority of age we can see lie between 31 to 40 years and least is 19 counts which lie above 50 yrs.
#
# average count can be seen between 31 to 50 years of age which do shopping.

# %%
sns.countplot(df['3 Which city do you shop online from?'])
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# city columns showing ncr region do more shopping as its showing more number of counts , and least count is showing bulanshahr which prefer online shopping

# %% [markdown]
# the shopping showing max female counts which is interested in shopping compare to male.
# female counts showing 181 where male counts showing 88 who prefer for shopping

# %%
sns.countplot(df['1Gender of respondent'])
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
sns.countplot(df['5 Since How Long You are Shopping Online ?'])
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %% [markdown]
# the above columns show the time period of doing shopping online, so max count is showing 98 who are doing shopping more than 4 years.
#
# the least count show 16 who are doing shopping or started and the time perios is 1 to 2 years

# %%
sns.countplot(df['6 How many times you have made an online purchase in the past 1 year?'])
df['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %% [markdown]
# from the last one year how many times you purchases items , so maximum count is showing 114 which indicate online purchase in a year and it is less than 10 times.
#
# least count is showing 6 which indicate above 42 times online purchases in a year.
#
# there is very less number of customer who do online purchase above 40 times in year, but generally customer do purchase less than 10 times in year

# %%
sns.countplot(df['7 How do you access the internet while shopping on-line?'])
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# most of the customer is using mobile internet to do online shopping which showing 142 count. and least number of customer are using dial up for shopping and it counts 4.

# %%
sns.countplot(df['8 Which device do you use to access the online shopping?'])
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# smartphone is mostly used for online shopping and it counts more compare to all other devices like laptop,desktop,tablet.
# tablet is very least used by customer to do online shopping.

# %%
sns.countplot(df['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '])
df['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %% [markdown]
# here we are comparing screen sizes of the devices used for online shopping.
# least count showing 7 which uses 5 inches mobile device for shopping whereas others using other devices like tablet, laptop, etc showing count of 134

# %%
sns.countplot(df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '])
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %% [markdown]
# windows is OS device used mostly showing count of 122 and least are using iOS/MAC showing count of 62.
# andriod OS is also used averagly showing count of 85

# %%
sns.countplot(df['11 What browser do you run on your device to access the website?\t\t\t                                                          '])
df['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %% [markdown]
# browser is being preffered Chrome which is generally used by every customer for online shopping. and it showing maximun count of 216 and very less count show 5 who are using Mozilla Firefox for online shopping.
#
# others customer are also using Safari and Opera for online shopping

# %%
sns.countplot(df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '])
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %% [markdown]
# channel being used by customer for the first time to reach to their favorite online store. here we see Search engine is mostly used to reach to their fav online store for shopping and very least count is showing approx 20 by content marketing and display marketing.
#
# here we can say that marketing and advertising are not working much as compare to searching or surfing by customer

# %%
sns.countplot(df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '])
df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %% [markdown]
# after searching for online store , then how can we use the store for shopping purpose.
#
# customer finds more easy to reach through search engine and downloading the app of store and very less count is observed by e-mail or social media.
#
# once customer know that or find their favorite store then they prefer searching and application for further purpose

# %%
sns.countplot(df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '])
df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %% [markdown]
# here we can observe how much time spend before purchasing anything from store. so it depend upon customer choice, but here we can see max time spend is taken 15 minutes and least time taken is 5min before purchasing anything

# %%
sns.countplot(df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '])
df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %% [markdown]
# here we see how payment mode is being preffered by customers in online shopping.
#
# max payment mode is preffered credit/debit cards showing count of 148 and least payment mode is preffered by e-wallets showing count of 45.
#
# other payment mode is also observed like cash on delivery

# %%
sns.countplot(df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '])
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %% [markdown]
# as we can know we can save the items of our choice and save to wishlist or shopping bag without payment, so that list we can observe here.
#
# most of the customers leave their choices in shopping bag and showing min count of 15, and sometimes who leaves on shopping cart their choices are very less and they count to 171

# %%
sns.countplot(df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %% [markdown]
# the abandom of bag /shopping cart is due to many factors and due to better alternative offer it is abandom and it shows most count of 133 and least count is showing 14 to abandom the bag due to no preffered mode of payment.

# %%
sns.countplot(df['18 The content on the website must be easy to read and understand'])
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %% [markdown]
# the content on website which is given is easy to read and understand , in this there are agree point count showing.
#
# in this strongly agree count is 164 and least agree count of 7 due to indifferent

# %%
sns.countplot(df['19 Information on similar product to the one highlighted  is important for product comparison'])
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %% [markdown]
# agreeing points which show information on similar product is important for product comparision , in this the customer strongly agree is 116 and least disagree count is 18

# %%
sns.countplot(df['20 Complete information on listed seller and product being offered is important for purchase decision.'])
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %% [markdown]
# the information is predicted on seller is offered for purchase decision is important or not.
#
# so maximum count of 101 shows agreeing of customers which beleive it is important and least count is 11 in which strongly agreeing of customers

# %%
sns.countplot(df['21 All relevant information on listed products must be stated clearly'])
df['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %% [markdown]
# the information is given to particular products is stated clearly or not, regarding to this agree and disagree counts are showing and other perceptions also showing.
#
# the max count of 132 is given who agree to this and least count of 12 is given which disagree to it.
# other opinions are also stated such as strongly agree count of 107 and strongly disagree count of 18.

# %%
sns.countplot(df['22 Ease of navigation in website'])
df['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %% [markdown]
# here ease of navigation is indicating to the correct/current location is identified by the store or not.
#
# here some of customers are agreed and some disagreed . count of strongly agree is showing 141 who found of correct navigation and very least disagree showing count of 5 who found wrong identification of navigation by store .
# others agree count shows 105 and Strongly disagree count is 18

# %%
sns.countplot(df['23 Loading and processing speed'])
df['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %% [markdown]
# the store loading and processing speed opinions are also given by customers , but major factor is depend upon the netwrok connection.
#
# strongly agree count is 115 which indicate the favor of speed of store and very less count is showing indifferent category which counts 12 and also strongly disagree which counts 12 who are not in favour of speed of store

# %%
sns.countplot(df['24 User friendly Interface of the website'])
df['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %% [markdown]
# user friendly means whether the store website is easy understandable by the customer or not, so many customer agree to it and many disagree.
#
# strongly agree count is showing 189 and least count is 5 which showing indifferent category.
# other opinions are also there, like agree showing 45 count,
# strongly disagree count showing 12

# %%
sns.countplot(df['25 Convenient Payment methods'])
df['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %% [markdown]
# there is many payments mode done by customers, whether it is convenient or not there are various opinions.
#
# strongly agreement is present which is showing maximum count of 159 and least count of 30 which indicate the disagree in convenient payment method

# %%
sns.countplot(df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'])
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %% [markdown]
# here , we can see that the transaction done by store is fullfilled at stipulated time or not or it will take much time to proceed. in this review here are many options agreeing to it or not.
#
# in this review strongly agree count is 141 and least indifferent count is 12 who not agree

# %%
sns.countplot(df['27 Empathy (readiness to assist with queries) towards the customers'])
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %% [markdown]
# the sympathy shown towards the customers by the store website is also showing so many views and opinions .
#
# strongly agree count is 194 who beleive in empathy towards customers and least count is 15 having indifferent category.

# %%
sns.countplot(df['28 Being able to guarantee the privacy of the customer'])
df['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %% [markdown]
# the privacy of the customer is being maintained or not,
# so here we see customers who strongly agree is 185 and least count is 26 showing indifferent

# %%
sns.countplot(df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'])
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %% [markdown]
# the communications channel of store is having various mode , so here some agree and some disagree to it. there is many mode like email, online rep, twitter, phone,etc.
#
# the response is given in different mode of communications and here strongly agree count is 149 and least having strongly disagree count of 11.

# %%
sns.countplot(df['30 Online shopping gives monetary benefit and discounts'])
df['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %% [markdown]
# the benefits and discounts given by store website when we doing online shopping, then in this most of the customers are agreeing to it and very less disagree to it. the coupons /discounts are provided when we do online shopping.
#
# strongly agree count is 105 who agree to this monetary benefit and less count of 11 who disagree to it.

# %%
sns.countplot(df['31 Enjoyment is derived from shopping online'])
df['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %% [markdown]
# here we see how enjoyment is being found who done online shopping, some found enjoyment and some dis agree to it.
#
# who strongly agree to it is showing count of 86 and least count is showing 19 count who is not agree .

# %%
sns.countplot(df['32 Shopping online is convenient and flexible'])
df['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %% [markdown]
# as some our customers are showing convenient to shop online and found flexible also from home .
#
# customers who found more convenient is showing 146 count and they are strongly agree to it but some of the customers who found less convenient and not happy with it showing count of 12 who are dis agree to it.

# %%
sns.countplot(df['33 Return and replacement policy of the e-tailer is important for purchase decision'])
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %% [markdown]
# the return and replacement policy is included in strore website who can return without any issue and argument.
#
# customers who agree with the policy of return decision is showing 198 count who are strongly agree and customers who dis agree with this policy is showing 20 count

# %%
sns.countplot(df['34 Gaining access to loyalty programs is a benefit of shopping online'])
df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %% [markdown]
# gaining the trust of customers by store website to maintain its policy and privacy is agreed by some customers and some dis agree by this.
#
# loyalty gained who agree by this customers show count of 115 and they are strongly agree to it and who not trust loyalty of store show count of 11 and they are strongly disagree to it.

# %%
sns.countplot(df['35 Displaying quality Information on the website improves satisfaction of customers'])
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %% [markdown]
# the information which displayed on website is satisfied by customer or not.
#
# customers who satisfied show the count of 133 and they are strongly agree to it
# customers who are not satisfied show the count of 56 and they are indifferent to it.

# %%
sns.countplot(df['36 User derive satisfaction while shopping on a good quality website or application'])
df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %% [markdown]
# the customer satisfied or not if they are doing shopping on the quality website .
#
# customers who beleive satisfied with the good quality website shopping show count of 175 and they are strongly agree to it.
# customers who do not satisfied with the quality of the website using show count of 8 who are dis agree to it.

# %%
sns.countplot(df['37 Net Benefit derived from shopping online can lead to users satisfaction'])
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %% [markdown]
# the benefits what we are getting after doing online shopping , so it is satisfied by the customer or not.
#
# customer who satisfied show count of 164 and they strongly agree to it
# customer who do not satisfied show count of 11 and they are dis agree to it.

# %%
sns.countplot(df['38 User satisfaction cannot exist without trust'])
df['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %% [markdown]
# customers satisfied only when they trust the store website for online shopping, so it is yes or no reviews given by customers.
#
# customers who trust show count of 122 and they strongly agree
# customers who do not trust show count of 5 and they are indifferent to it

# %%
sns.countplot(df['39 Offering a wide variety of listed product in several category'])
df['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %% [markdown]
# there are many varities and category under a particular listed product name, so it is agree that they provide various category or not.
#
# customers who say that website provide various category show count of 111 and they are strongly agree
# customers who say that website do not provide various category show count of 7 and they are dis agree to it

# %%
sns.countplot(df['40 Provision of complete and relevant product information'])
df['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %% [markdown]
# the complte information for the product name is given by website or not.
#
# customers who satisfied , say that it is given relevant information show count of 135 and they strongly agree
# customers who do not satisfied , say relevant information not given show count of 5 anf they dis agree to it.

# %%
sns.countplot(df['41 Monetary savings'])
df['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %% [markdown]
# while online shopping there is savings of money, so there is money saving is there or not while doing online shopping.
#
# customers who say that there is savings of money while doing online shopping show count of 148 and they strongly agree to it.
# customers who say that there is no savings of money while doing online shopping show count of 15 and they indifferent

# %%
sns.countplot(df['42 The Convenience of patronizing the online retailer'])
df['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %% [markdown]
# customer is regular customer of online shopping or not,
#
# customer who is regular customer of online shopping show count of 138 and they agree to it
# customer who is not a  regular customer of online shopping show count of 54 and they strongly dis agree to it

# %%
sns.countplot(df['43 Shopping on the website gives you the sense of adventure'])
df['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %% [markdown]
# while doing online shopping there is any adventure present or not,
#
# customer who sense the adventure show the count of 101 and they agree to it
# customer who do not sense the adventure show the count of 5 and they strongly dis agree to it.

# %%
sns.countplot(df['44 Shopping on your preferred e-tailer enhances your social status'])
df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %% [markdown]
# doing online shopping (e-tailor ) enhances/increase the status of social status or not,
#
# customer who think that social status enhances show count of indifferent 100
# customer who dont think that social status enhances show count of 29 and they dis agree to it.

# %%
sns.countplot(df['45 You feel gratification shopping on your favorite e-tailer'])
df['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %% [markdown]
# customers who feel satisfied/pleasure while doing shopping on their favourite e tailor,
#
# customer who feel pleasure show count of 101 and they are indifferent
# customer who do not feel pleasure show count of 18 and they are strongly dis agree

# %%
sns.countplot(df['46 Shopping on the website helps you fulfill certain roles'])
df['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %% [markdown]
# shopping on the websites that fulfill certain roles of customer or not,
#
# customer whose roles fulfill show count of 88 and they are agree to it.
# customer who dont feel their roles fulfill show count of 22 and they dis agree to it.

# %%
sns.countplot(df['47 Getting value for money spent'])
df['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %% [markdown]
# there is any value customer get while spending money,
#
# customer who think that they get value while spending money show count of 149 and they agree to this.
# customer who do not think that they get value while spending money show count of 38 and they indifferent to this.

# %%
sns.countplot(df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '])
df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %% [markdown]
# different websites name show in list, which prefer for online shopping,
#
# customer used many websites for online shopping but mostly used website name is amazon, flipkart, paytm, myntra, snapdeal which show count of 82.
# customer who uses website and least used show count of 7 and their names is amazon, flipkart paytm.

# %%
sns.countplot(df['Easy to use website or application'])
df['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %% [markdown]
# the website which is easy to use and search everything very easily and perform all operations,
#
# website which is easy to use show countof 64 and their name is amazon, flipkart, paytm, myntra, snapdeal.
# website which is not easy to use having difficulty to use show count of 7 and their name is amazon, paytm.

# %%
sns.countplot(df['Visual appealing web-page layout'])
df['Visual appealing web-page layout'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Myntra.com                                                      15
# Flipkart.com, Myntra.com                                        15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %% [markdown]
# the layout of the web page is available in format or not,
# customers who agree with this is show count of 87 and their website name is amazon, flipkart.
# customers who dont agree with this show count of 11 and their websites names is paytm,snapdeal,flipkart

# %%
sns.countplot(df['Wild variety of product on offer'])
df['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %% [markdown]
# the variety of product on offer,  while running offer how many products included in count .
#
# amazon, flipkart show max count of 130 which show variety of product and least paytm used count is 7.

# %%
sns.countplot(df['Complete, relevant description information of products'])
df['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %% [markdown]
# the information gives the complete information of the product ,
#
# websites which gave complete information is amazon, flipkart show count of 100 and snapdeal show the least count of 7 which show less information of product.

# %%
sns.countplot(df['Fast loading website speed of website and application'])
df['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %% [markdown]
# the speed of website while operating is sufficient according to the customer or not,
#
# customers who agree with speed of website is sufficient show count of 51 and their websites name is amazon.
# customers who dont agree with speed of websites is sufficient show count of 8 and their websites name is flipkart.

# %%
sns.countplot(df['Reliability of the website or application'])
df['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %% [markdown]
# website can be trusted or not ,
#
# customers who trusted the website show count of 61 and they think reliable and their name is amazon.
# customers who dont trusted the website show the count of 12 and they think not reliable and their name is paytm.

# %%
sns.countplot(df['Quickness to complete purchase'])
df['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %% [markdown]
# which website is speedily do the purchasing process,
#
# so here we can see the amazon websites who can do the speedily purchases is amazon and it show max count of 66.
# website like flipkart, myntra, snapdeal who take some time for purchasing and show min count of 14.

# %%
sns.countplot(df['Availability of several payment options'])
df['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %% [markdown]
# which website having different mode of payment available ,
#
# amazon, flipkart having different mode of payment available and it show max count of 65.
# flipkart also showing less count of 8 which also indicate the less payment mode available.

# %%
sns.countplot(df['Speedy order delivery '])
df['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %% [markdown]
# deliver time taken by website, which website take max time and which take min time to deliver the product.
# amazon show max count and indicate that it takes less time to deliver the product.
# flipkart, myntra, snapdeal we can see it take more time to deliver the product and it show the less count of 14.

# %%
sns.countplot(df['Privacy of customers’ information'])
df['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Myntra.com                                                      15
# Amazon.in, Paytm.com                                            15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %% [markdown]
# the privacy of customers is maintained by websites or not,
# amazon is showing high count and it indicate that it maintained the privacy information of customers.
# whereas flipkart, snapdeal show less count of 7 and it indicate that it does not maintained much privacy of customers.

# %%
sns.countplot(df['Security of customer financial information'])
df['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Myntra.com                                                      15
# Paytm.com                                                       15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %% [markdown]
# customer of financial information is keep securely or not,
# amazon show the max count 51 which indicate that it keep secure the information whereas flipkart , paytm not able to secure safely the financial information of customers

# %%
sns.countplot(df['Perceived Trustworthiness'])
df['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
sns.countplot(df['Presence of online assistance through multi-channel'])
df['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %% [markdown]
# amazon, flipkart,myntra, snapdeal show multi channel of 61 and it show max count. whereas flipkart show less mutli channel assistance and it show laset count of 8.

# %%
sns.countplot(df['Longer time to get logged in (promotion, sales period)'])
df['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Amazon.in, Flipkart.com                  38
# Paytm.com                                38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
sns.countplot(df['Longer time in displaying graphics and photos (promotion, sales period)'])
df['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %% [markdown]
# amazon, flipkart takes longer time to display grpahics and photos whereas paytm is less count

# %%
sns.countplot(df['Late declaration of price (promotion, sales period)'])
df['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Flipkart.com               38
# Amazon.in                  38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
sns.countplot(df['Longer page loading time (promotion, sales period)'])
df['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %% [markdown]
# myntra website takes long time to downloading the page whereas amazon,paytm takes less time for downloadingt the page.

# %%
sns.countplot(df['Limited mode of payment on most products (promotion, sales period)'])
df['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %% [markdown]
# snapdeal show limited mode of payment whereas myntra show more  number of payment mode and it counts very less.

# %%
sns.countplot(df['Longer delivery period'])
df['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %% [markdown]
# paytm website show max deliver time to reach to customers whereas myntra take less deliver time to reach to customers.

# %%
sns.countplot(df['Change in website/Application design'])
df['Change in website/Application design'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %% [markdown]
# amazon show more changes in their website whereas flipkart, myntra show very less changes in their websites.

# %%
sns.countplot(df['Frequent disruption when moving from one page to another'])
df['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %% [markdown]
# amazon showing less inteference from jumping from one page to next page whereas flipkart, snapdeal show more interference to moving to next page.

# %%
sns.countplot(df['Website is as efficient as before'])
df['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %% [markdown]
# amazon keep its dignity and position to be as efficient as before and it show max count of 94.
# whereas snapdeal decreses its efficiency same as before .

# %%
sns.countplot(df['Which of the Indian online retailer would you recommend to a friend?'])
df['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %% [markdown]
# amazon website is mostly preffered by customers and they prefer to their friend also for continuing with this website for online shopping.
# flipkart, paytm, myntra, snapdeal show less preffered by customers to their friend and it counts 11.

# %%
sns.pairplot(df)

# %% [markdown]
# only numeric data type plot on sns.pairplot, rest of the columns are object type.

# %% [markdown]
# CONCLUSION

# %% [markdown]
# the above datasets loaded and made EDA process which include the visualization and some basic checking of datasets.
# from graph we can conclude most of the points like satisfaction, build trust, provide good quality, maintain the security, provide full information, etc.
#
# then only customer retention can be maintained and increses the count of new customer also.
