# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel(r'C:\Users\Hp\Desktop\data trained\internshp\Data file.xlsx')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df.head(4)
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0      3055.050      3065.150
# 1           2      1  76462I70374  712.0     12122.000     12124.750
# 2           3      1  17943I70372  535.0      1398.000      1398.000
# 3           4      1  55773I70781  241.0        21.228        21.228
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# 1             12.0                 0.0          1.0            12
# 2              6.0                 0.0          1.0             6
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111670  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228330  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
df.tail(3)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209590      209591      1  28556I85350  1013.0   11843.11167      11904.35
# 209591      209592      1  59712I82733  1732.0   12488.22833      12574.37
# 209592      209593      1  65061I85339  1581.0    4489.36200       4534.82
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 209590             12.0                 0.0          6.0            54
# 209591             12.0                 0.0          3.0            24
# 209592             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# ...

# %%
df.sample()
# Out:
#         Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 116583      116584      1  46700I88659  738.0         9.144         9.144
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 116583     87.12     87.12                2.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 116583              6.0                 0.0          1.0             6
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 116583                6                 0.0        0.0        0.0      UPW
#
#             pdate
# 116583 2016-06-12
#
# [1 rows x 37 columns]

# %%
df.sample(2)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 195432      195433      1  81143I89237  1198.0    105.025667    105.025667
# 48147        48148      1  60437I89235   151.0     45.406667     45.406667
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 195432    990.38    990.38                3.0                0.0  ...
# 48147      98.00     98.00                4.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 195432              6.0                 0.0          5.0            30
# 48147               6.0                 0.0          1.0             6
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 195432                6                 0.0       3.25       3.25      UPW
# 48147                 6                 0.0       0.00       0.00      UPW
#
#             pdate
# 195432 2016-06-23
# 48147  2016-06-14
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  int64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (209593, 37)

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755200  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000       209593.00000
# mean     6082.515068    2692.581910    3483.406534         3755.84780
# std     10918.812767    4308.586781    5770.461279        53905.89223
# min       -93.012667  -23737.140000  -24720.580000          -29.00000
# ...

# %%
df.describe(include='all')
# Out:
#            Unnamed: 0          label       msisdn            aon  \
# count   209593.000000  209593.000000       209593  209593.000000
# unique            NaN            NaN       186243            NaN
# top               NaN            NaN  04581I85330            NaN
# freq              NaN            NaN            7            NaN
# first             NaN            NaN          NaN            NaN
# last              NaN            NaN          NaN            NaN
# mean    104797.000000       0.875177          NaN    8112.343445
# std      60504.431823       0.330519          NaN   75696.082531
# min          1.000000       0.000000          NaN     -48.000000
# 25%      52399.000000       1.000000          NaN     246.000000
# 50%     104797.000000       1.000000          NaN     527.000000
# 75%     157195.000000       1.000000          NaN     982.000000
# max     209593.000000       1.000000          NaN  999860.755200
#
# ...

# %% [markdown]
# observation:
#
#      1-- the statistics of numeric and string both data type are shown.
#      2-- the count of rows in data sets are 209593 , which showing no null values present.
#      3-- the string data type showing the unique , top data value in top row, and its frequency showing.
#      4-- mean, std, min, max values and different percentage percentile showing.
#      5-- there is a vast difference between mean and std deviation value, spreading of data is there.
#      6-- there is difference between 75% percentile and max value, then it indicates the presence of val

# %% [markdown]
# VISUALIZATION

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df_corr=df.corr()
df_corr
# Out:
#                       Unnamed: 0     label       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403 -0.002048      0.002739
# label                   0.000403  1.000000 -0.003785      0.168298
# aon                    -0.002048 -0.003785  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804  0.004256      0.275837
# cnt_ma_rech30           0.003320  0.237331 -0.003148      0.451385
# fr_ma_rech30            0.003181  0.001330 -0.001163     -0.000577
# sumamnt_ma_rech30       0.000123  0.202828  0.000707      0.636536
# ...

# %%
plt.figure(figsize=(50,20))
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# observation:
#
#     1-- the positive and negative values both given.
#     2-- the positive value indicate the directly proportional relational whereas negative values indicate the inversely proportionally relational.
#     3-- the daily decr, rental columns is mostly correlated with the each other compare to all given columns.
#     4-- cnt loan, payback are also holding high correlated value.

# %%
df.dtypes
# Out:
# Unnamed: 0                       int64
# label                            int64
# msisdn                          object
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30                int64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# ...

# %% [markdown]
# univariant

# %%
sns.scatterplot(df['Unnamed: 0'], df['label'])
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='label'>

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
sns.countplot(df['msisdn'], df['label'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 sns.countplot(df['msisdn'], df['label'])
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:3596, in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3594     y = x
#    3595 elif x is not None and y is not None:
# ...

# %%
sns.countplot(df['aon'])

# %%
sns.countplot(df['daily_decr30'])

# %%
sns.countplot(df['daily_decr90'])

# %%
sns.countplot(df['rental30'])

# %%
sns.countplot(df['rental90'])

# %%
sns.countplot(df['last_rech_date_ma'])

# %%
sns.countplot(df['last_rech_date_da'])

# %%
sns.countplot(df['last_rech_amt_ma'])

# %%
sns.countplot(df['cnt_ma_rech30'])

# %%
sns.countplot(df['fr_ma_rech30'])

# %%
sns.countplot(df['sumamnt_ma_rech30'])

# %%
sns.countplot(df['medianamnt_ma_rech30'])

# %%
sns.countplot(df['medianmarechprebal30'])

# %%
sns.countplot(df['cnt_ma_rech90'])

# %%
sns.countplot(df['fr_ma_rech90'])

# %%
sns.countplot(df['sumamnt_ma_rech90'])

# %%
sns.countplot(df['medianamnt_ma_rech90'])

# %%
sns.countplot(df['medianmarechprebal90'])

# %%
sns.countplot(df['cnt_da_rech30'])

# %%
sns.countplot(df['fr_da_rech30'])

# %%
sns.countplot(df['cnt_da_rech90'])

# %%
sns.countplot(df['fr_da_rech90'])

# %%
sns.countplot(df['cnt_loans30'])

# %%
sns.countplot(df['amnt_loans30'])

# %%
sns.countplot(df['maxamnt_loans30'])

# %%
sns.countplot(df['medianamnt_loans30'])

# %%
sns.countplot(df['cnt_loans90'])

# %%
sns.countplot(df['amnt_loans90'])

# %%
sns.countplot(df['maxamnt_loans90'])

# %%
sns.countplot(df['medianamnt_loans90'])

# %%
sns.countplot(df['payback30'])

# %%
sns.countplot(df['payback90'])

# %%
sns.countplot(df['pcircle'])

# %%
sns.countplot(df['pdate'])

# %%
df.columns

# %% [markdown]
# LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.columns:
    df[i]=le.fit_transform(df[i])

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# label                   int64
# msisdn                  int32
# aon                     int64
# daily_decr30            int64
# daily_decr90            int64
# rental30                int64
# rental90                int64
# last_rech_date_ma       int64
# last_rech_date_da       int64
# last_rech_amt_ma        int64
# cnt_ma_rech30           int64
# fr_ma_rech30            int64
# sumamnt_ma_rech30       int64
# medianamnt_ma_rech30    int64
# medianmarechprebal30    int64
# cnt_ma_rech90           int64
# fr_ma_rech90            int64
# sumamnt_ma_rech90       int64
# medianamnt_ma_rech90    int64
# medianmarechprebal90    int64
# cnt_da_rech30           int64
# fr_da_rech30            int64
# cnt_da_rech90           int64
# fr_da_rech90            int64
# cnt_loans30             int64
# amnt_loans30            int64
# maxamnt_loans30         int64
# medianamnt_loans30      int64
# cnt_loans90             int64
# amnt_loans90            int64
# ...

# %% [markdown]
# CHECKING FOR OUTLIERS

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
plt.boxplot(df['Unnamed: 0'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94ff43a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94ff4a00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94ff40d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94ff4ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94fef1f0>],
#  'means': []}

# %%
plt.boxplot(df['label'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94fb5940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94fb5ee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94fb5670>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94f954c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94f95790>],
#  'means': []}

# %%
plt.boxplot(df['msisdn'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94c826d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94c82c70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94c82400>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94c9c250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94c9c520>],
#  'means': []}

# %%
plt.boxplot(df['aon'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94c672b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94c67850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94c73e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94c67df0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94c47100>],
#  'means': []}

# %%
plt.boxplot(df['daily_decr30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94ad9d90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94acd370>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94ad9ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94acd910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94acdbe0>],
#  'means': []}

# %%
plt.boxplot(df['daily_decr90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94ad5cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe949112b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94ad5a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94911850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94911b20>],
#  'means': []}

# %%
plt.boxplot(df['rental30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe947bed90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe947a6370>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe947beac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe947a6910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe947a6be0>],
#  'means': []}

# %%
plt.boxplot(df['rental90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe947025b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94702b50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe947022e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe9473b130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe9473b400>],
#  'means': []}

# %%
plt.boxplot(df['last_rech_date_ma'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94541370>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94541910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe945410a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94541eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe945661c0>],
#  'means': []}

# %%
plt.boxplot(df['last_rech_date_da'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9452e9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe9452ef70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9452e700>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe9452a550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe9452a820>],
#  'means': []}

# %%
plt.boxplot(df['last_rech_amt_ma'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe943a71c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe943a7760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94394eb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe943a7d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe943a7fd0>],
#  'means': []}

# %%
plt.boxplot(df['cnt_ma_rech30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94358e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe93abf460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94358bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe93abfa00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe93abfcd0>],
#  'means': []}

# %%
plt.boxplot(df['fr_ma_rech30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9392cc70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe938fd250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9392c9a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe938fd7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe938fdac0>],
#  'means': []}

# %%
plt.boxplot(df['sumamnt_ma_rech30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9346de20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe93460400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9346db50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe934609a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe93460c70>],
#  'means': []}

# %%
plt.boxplot(df['medianamnt_ma_rech30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe93407b80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe95014160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe934078b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe95014700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe950149d0>],
#  'means': []}

# %%
plt.boxplot(df['medianmarechprebal30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe95073d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe9508f2e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe95073a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe9508f880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe9508fb50>],
#  'means': []}

# %%
plt.boxplot(df['cnt_ma_rech90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe95a10dc0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe950a13a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe95a10af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe950a1940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe950a1c10>],
#  'means': []}

# %%
plt.boxplot(df['cnt_da_rech90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9510af10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe950f64f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9510ac40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe950f6a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe950f6d60>],
#  'means': []}

# %%
plt.boxplot(df['fr_da_rech90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe954cd550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe954cdaf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe954cd280>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe954ab0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe954ab3a0>],
#  'means': []}

# %%
plt.boxplot(df['cnt_loans30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe95510cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe955622b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe95510a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe95562850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe95562b20>],
#  'means': []}

# %%
plt.boxplot(df['amnt_loans30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe957191c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe95719760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9574feb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe95719d00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe95719fd0>],
#  'means': []}

# %%
plt.boxplot(df['maxamnt_loans30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe957d9b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe957f1130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe957d9880>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe957f16d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe957f19a0>],
#  'means': []}

# %%
plt.boxplot(df['medianamnt_loans30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9585ccd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe958672b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9585ca00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe95867850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe95867b20>],
#  'means': []}

# %%
plt.boxplot(df['cnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe95939eb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe95911490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe95939be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe95911a30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe95911d00>],
#  'means': []}

# %%
plt.boxplot(df['amnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe949b1fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94a035b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe949b1d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94a03b50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94a03e20>],
#  'means': []}

# %%
plt.boxplot(df['maxamnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94a90d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94aae310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94a90a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94aae8b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94aaeb80>],
#  'means': []}

# %%
plt.boxplot(df['medianamnt_loans30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe95d1b1c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe95d1b760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe95d1ceb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe95d1bd00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe95d1bfd0>],
#  'means': []}

# %%
plt.boxplot(df['cnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe95d4df70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe95dce550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe95d4dca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe95dceaf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe95dcedc0>],
#  'means': []}

# %%
plt.boxplot(df['amnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe94e42130>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe94e426d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe94e74e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe94e42c70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe94e42f40>],
#  'means': []}

# %%
plt.boxplot(df['maxamnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe96106d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe9611a2e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe96106a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe9611a880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe9611ab50>],
#  'means': []}

# %%
plt.boxplot(df['medianamnt_loans90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9615ef10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe961c14f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9615ec40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe961c1a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe961c1d60>],
#  'means': []}

# %%
plt.boxplot(df['payback30'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9621d430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe9621d9d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9621d160>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe9621df70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe96226280>],
#  'means': []}

# %%
plt.boxplot(df['payback90'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe9628adf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe962aa3d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe9628ab20>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe962aa970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe962aac40>],
#  'means': []}

# %%
plt.boxplot(df['pcircle'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe962cca00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe962ccfa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe962cc730>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe962d3580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe962d3850>],
#  'means': []}

# %%
plt.boxplot(df['pdate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fe964a4670>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fe964a4c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fe964a43a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fe9648b1f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fe9648b4c0>],
#  'means': []}

# %% [markdown]
# REMOVING OUTLIERS

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#         Unnamed: 0     label    msisdn       aon  daily_decr30  daily_decr90  \
# 0         1.732043  2.647896  0.984213  0.718760      0.309321      0.198930
# 1         1.732026  0.377658  0.915027  0.050175      1.239146      1.185962
# 2         1.732009  0.377658  1.106929  0.259147      0.035654      0.100304
# 3         1.731993  0.377658  0.205668  0.772935      1.175385      1.143529
# 4         1.731976  0.377658  1.603298  0.460856      0.448050      0.445099
# ...            ...       ...       ...       ...           ...           ...
# 209588    1.731976  0.377658  0.934453  0.488080      0.445758      0.442916
# 209589    1.731993  0.377658  1.583891  0.684546      0.993631      0.969669
# 209590    1.732009  0.377658  0.727434  0.576196      1.223743      1.171183
# 209591    1.732026  0.377658  0.340177  1.832705      1.258724      1.214539
# 209592    1.732043  0.377658  0.523869  1.568820      0.540507      0.424637
#
# ...

# %%
print(np.where(z>3))
# Out:
# (array([    21,     22,     28, ..., 209587, 209587, 209587], dtype=int64), array([17, 17, 13, ..., 15, 28, 32], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, label, msisdn, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, pcircle, pdate]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# here not showing any rows after removing outliers from zscore method,  so we dont removing any outliers for right now

# %% [markdown]
# CHECKING FOR SKEWNESS

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
sns.distplot(df['Unnamed: 0'])
# Out:
# <AxesSubplot:xlabel='Unnamed: 0', ylabel='Density'>

# %%
sns.distplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='Density'>

# %%
sns.distplot(df['msisdn'])
# Out:
# <AxesSubplot:xlabel='msisdn', ylabel='Density'>

# %%
sns.distplot(df['aon'])
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %%
sns.distplot(df['daily_decr30'])
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Density'>

# %%
sns.distplot(df['daily_decr90'])
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='Density'>

# %%
sns.distplot(df['rental30'])
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='Density'>

# %%
sns.distplot(df['rental90'])
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Density'>

# %%
sns.distplot(df['last_rech_date_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Density'>

# %%
sns.distplot(df['last_rech_date_da'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_da', ylabel='Density'>

# %%
sns.distplot(df['last_rech_amt_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='Density'>

# %%
sns.distplot(df['cnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['fr_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df['medianmarechprebal30'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='Density'>

# %%
sns.distplot(df['cnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['fr_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['sumamnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech90', ylabel='Density'>

# %%
sns.distplot(df['medianmarechprebal90'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='Density'>

# %%
sns.distplot(df['cnt_da_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech30', ylabel='Density'>

# %%
sns.distplot(df['fr_da_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech30', ylabel='Density'>

# %%
sns.distplot(df['cnt_da_rech90'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech90', ylabel='Density'>

# %%
sns.distplot(df['fr_da_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech90', ylabel='Density'>

# %%
sns.distplot(df['cnt_loans30'])
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['amnt_loans30'])
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['maxamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='Density'>

# %%
sns.distplot(df['cnt_loans90'])
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['maxamnt_loans90'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['medianamnt_loans90'])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans90', ylabel='Density'>

# %%
sns.distplot(df['payback30'])
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='Density'>

# %%
sns.distplot(df['payback90'])
# Out:
# <AxesSubplot:xlabel='payback90', ylabel='Density'>

# %%
sns.distplot(df['pcircle'])
# Out:
# <AxesSubplot:xlabel='pcircle', ylabel='Density'>

# %%
sns.distplot(df['pdate'])
# Out:
# <AxesSubplot:xlabel='pdate', ylabel='Density'>

# %% [markdown]
# REMOVING SKEWNESS

# %%
from sklearn.preprocessing import power_transform

# %%
df.skew()
# Out:
# Unnamed: 0               0.000000
# label                   -2.270254
# msisdn                   0.000719
# aon                      1.806204
# daily_decr30             0.087551
# daily_decr90             0.228175
# rental30                 0.449031
# rental90                 0.466723
# last_rech_date_ma       16.524637
# last_rech_date_da       16.904463
# last_rech_amt_ma         1.074621
# cnt_ma_rech30            2.684106
# fr_ma_rech30            17.638960
# sumamnt_ma_rech30        2.269945
# medianamnt_ma_rech30     2.035013
# medianmarechprebal30     1.416150
# cnt_ma_rech90            2.886544
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        1.732703
# medianamnt_ma_rech90     2.086845
# medianmarechprebal90     1.372093
# cnt_da_rech30           18.137741
# fr_da_rech30            18.084817
# cnt_da_rech90           23.642903
# fr_da_rech90            26.899282
# cnt_loans30              2.685234
# amnt_loans30             2.955552
# ...

# %%
df.drop(['Unnamed: 0', 'pcircle'], inplace=True, axis=1)

# %%
df.skew()
# Out:
# label                   -2.270254
# msisdn                   0.000719
# aon                      1.806204
# daily_decr30             0.087551
# daily_decr90             0.228175
# rental30                 0.449031
# rental90                 0.466723
# last_rech_date_ma       16.524637
# last_rech_date_da       16.904463
# last_rech_amt_ma         1.074621
# cnt_ma_rech30            2.684106
# fr_ma_rech30            17.638960
# sumamnt_ma_rech30        2.269945
# medianamnt_ma_rech30     2.035013
# medianmarechprebal30     1.416150
# cnt_ma_rech90            2.886544
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        1.732703
# medianamnt_ma_rech90     2.086845
# medianmarechprebal90     1.372093
# cnt_da_rech30           18.137741
# fr_da_rech30            18.084817
# cnt_da_rech90           23.642903
# fr_da_rech90            26.899282
# cnt_loans30              2.685234
# amnt_loans30             2.955552
# maxamnt_loans30         18.285158
# ...

# %%
x=df.drop('label', axis=1)
x
# Out:
#         msisdn   aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        40191   279         80180         76157     13778     14851
# 1       142291   719        121168        121370     87076     83052
# 2        33594   542         64973         62450     38625     34572
# 3       104157   248         14732         14663     11258     11135
# 4         6910   954         46794         46656     44372     39798
# ...        ...   ...           ...           ...       ...       ...
# 209588   42866   411         46895         46756     44066     39548
# 209589  178248  1082         22744         22627     59433     53907
# 209590   53995  1020        120489        120693    104193    116375
# 209591  111388  1739        122031        122679     21540     36833
# 209592  121263  1588         90371         86496     24242     26856
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
y=df['label']
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %%
X=power_transform(x)
X
# Out:
# array([[-0.92855164, -0.68070707,  0.42946079, ...,  1.28594442,
#          1.21122748,  0.57775419],
#        [ 0.90402732,  0.36130212,  1.13079298, ..., -0.95865368,
#         -1.05695822,  1.36067787],
#        [-1.07962307,  0.02609381,  0.13331507, ..., -0.95865368,
#         -1.05695822,  1.67272967],
#        ...,
#        [-0.63401932,  0.80743456,  1.1200442 , ...,  1.06572313,
#          0.95333192,  0.92409065],
#        [ 0.41109115,  1.56099594,  1.14441945, ..., -0.95865368,
#          1.11245482,  0.77241039],
#        [ 0.57252135,  1.42609049,  0.61526454, ..., -0.95865368,
#         -1.05695822,  0.03958262]])

# %%
X_new=pd.DataFrame(X, columns=x.columns)
X_new
# Out:
#           msisdn       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      -0.928552 -0.680707      0.429461      0.353770 -0.960018 -0.922677
# 1       0.904027  0.361302      1.130793      1.096693  0.942917  0.799883
# 2      -1.079623  0.026094      0.133315      0.091741 -0.069722 -0.218310
# 3       0.290212 -0.795125     -1.168988     -1.147585 -1.095406 -1.114908
# 4      -1.832104  0.719297     -0.260760     -0.244132  0.080620 -0.077030
# ...          ...       ...           ...           ...       ...       ...
# 209588 -0.869410 -0.281610     -0.258415     -0.241860  0.072920 -0.083519
# 209589  1.439485  0.886315     -0.898304     -0.875168  0.426053  0.254864
# 209590 -0.634019  0.807435      1.120044      1.086579  1.214453  1.293043
# 209591  0.411091  1.560996      1.144419      1.116180 -0.618633 -0.155679
# 209592  0.572521  1.426090      0.615265      0.537861 -0.517663 -0.453343
#
# ...

# %%
X_new.skew()
# Out:
# msisdn                  -0.291511
# aon                     -0.014895
# daily_decr30            -0.351383
# daily_decr90            -0.306594
# rental30                -0.176378
# rental90                -0.170922
# last_rech_date_ma       -0.405624
# last_rech_date_da      -25.420242
# last_rech_amt_ma        -0.081810
# cnt_ma_rech30           -0.000221
# fr_ma_rech30             0.147462
# sumamnt_ma_rech30       -0.130283
# medianamnt_ma_rech30    -0.069444
# medianmarechprebal30    -0.012164
# cnt_ma_rech90           -0.002551
# fr_ma_rech90             0.142952
# sumamnt_ma_rech90       -0.185277
# medianamnt_ma_rech90    -0.043751
# medianmarechprebal90    -0.012069
# cnt_da_rech30            6.925820
# fr_da_rech30            11.390665
# cnt_da_rech90            6.006577
# fr_da_rech90            15.469700
# cnt_loans30              0.036257
# amnt_loans30             0.037947
# maxamnt_loans30         -1.110382
# medianamnt_loans30       3.447735
# ...

# %%
df['last_rech_date_da']=np.log(df['last_rech_date_da'])
df['cnt_da_rech30']=np.log(df['cnt_da_rech30'])
df['fr_da_rech30']=np.log(df['fr_da_rech30'])
df['fr_da_rech90']=np.log(df['fr_da_rech90'])
df['medianamnt_loans30']=np.log(df['medianamnt_loans30'])
df['medianamnt_loans90']=np.log(df['medianamnt_loans90'])

# %% [markdown]
# TRAINING DATA

# %%
df['label'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# checking for max random state

# %%
X_new
# Out:
#           msisdn       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      -0.928552 -0.680707      0.429461      0.353770 -0.960018 -0.922677
# 1       0.904027  0.361302      1.130793      1.096693  0.942917  0.799883
# 2      -1.079623  0.026094      0.133315      0.091741 -0.069722 -0.218310
# 3       0.290212 -0.795125     -1.168988     -1.147585 -1.095406 -1.114908
# 4      -1.832104  0.719297     -0.260760     -0.244132  0.080620 -0.077030
# ...          ...       ...           ...           ...       ...       ...
# 209588 -0.869410 -0.281610     -0.258415     -0.241860  0.072920 -0.083519
# 209589  1.439485  0.886315     -0.898304     -0.875168  0.426053  0.254864
# 209590 -0.634019  0.807435      1.120044      1.086579  1.214453  1.293043
# 209591  0.411091  1.560996      1.144419      1.116180 -0.618633 -0.155679
# 209592  0.572521  1.426090      0.615265      0.537861 -0.517663 -0.453343
#
# ...

# %%
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 209593, dtype: int64

# %%
maxAcc=0
maxRS=0
lr=LogisticRegression()

for i in range(1,200):
    x_train, x_test, y_train, y_test=train_test_split(X_new, y, test_size=0.20, random_state=i)
    lr.fit(x_train, y_train)
    y_pred=lr.predict(x_test)
    score=accuracy_score(y_test, y_pred)
    print('score is ', score, ' random state is ', i)
    
    if score>maxAcc:
        maxAcc=score
        maxRS=i
        print('max score is ',maxAcc, ' at random state ',maxRS)
# Out:
# score is  0.896490851403898  random state is  1
# max score is  0.896490851403898  at random state  1
# score is  0.8952503637968463  random state is  2
# score is  0.8957990410076576  random state is  3
# score is  0.8970395286147094  random state is  4
# max score is  0.8970395286147094  at random state  4
# score is  0.8934373434480785  random state is  5
# score is  0.8973257949855674  random state is  6
# max score is  0.8973257949855674  at random state  6
# score is  0.8914334788520718  random state is  7
# score is  0.8952742193277511  random state is  8
# score is  0.8957036188840383  random state is  9
# score is  0.8957513299458479  random state is  10
# score is  0.894987952956893  random state is  11
# score is  0.8930317994226962  random state is  12
# score is  0.8958467520694673  random state is  13
# score is  0.8962045850330399  random state is  14
# score is  0.8952026527350366  random state is  15
# score is  0.8961568739712302  random state is  16
# ...

# %% [markdown]
# max accuracy score is 90.047 % at random state 77

# %%
lr=LogisticRegression()
gnb=GaussianNB()
dtc=DecisionTreeClassifier()
rfc=RandomForestClassifier()
knn=KNeighborsClassifier()

x_train, x_test, y_train, y_test=train_test_split(X_new, y, test_size=0.20, random_state=77)
list=[lr, gnb, dtc, rfc, knn]
for i in list:
    i.fit(x_train, y_train)
    y_pred=i.predict(x_test)
    print('\n\n\n The result of ',i,' is :')
    print('\n Accuracy_score is ', accuracy_score(y_test, y_pred))
    print('\n confusion matrix \n', confusion_matrix(y_test, y_pred))
    print('\n classification matrix \n', classification_report(y_test, y_pred))
# Out:
#  The result of  LogisticRegression()  is :
#
#  Accuracy_score is  0.9004747250650064
#
#  confusion matrix
#  [[ 1467  3644]
#  [  528 36280]]
#
#  classification matrix
#                precision    recall  f1-score   support
#
#            0       0.74      0.29      0.41      5111
#            1       0.91      0.99      0.95     36808
#
#     accuracy                           0.90     41919
#    macro avg       0.82      0.64      0.68     41919
# weighted avg       0.89      0.90      0.88     41919
#
#
#
#
#  The result of  GaussianNB()  is :
#
#  Accuracy_score is  0.7574846728213936
#
#  confusion matrix
#  [[ 3896  1215]
#  [ 8951 27857]]
#
#  classification matrix
#                precision    recall  f1-score   support
#
#            0       0.30      0.76      0.43      5111
#            1       0.96      0.76      0.85     36808
#
#     accuracy                           0.76     41919
#    macro avg       0.63      0.76      0.64     41919
# ...

# %% [markdown]
# best score from above given model is 92.34 % and model name is random forest classifier

# %% [markdown]
# CROSS VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in list:
    scr=cross_val_score(i, X_new, y, cv=5)
    print('\n cross validation score of ',i,' is ', scr.mean())
# Out:
#  cross validation score of  LogisticRegression()  is  0.8958743877897533
#
#  cross validation score of  GaussianNB()  is  0.7550299945768988
#
#  cross validation score of  DecisionTreeClassifier()  is  0.8836697850417708
#
#  cross validation score of  RandomForestClassifier()  is  0.9211471812603916
#
#  cross validation score of  KNeighborsClassifier()  is  0.900802985547408

# %% [markdown]
# best fitted model is random forest classifier which having maximum score of 92.11 % and we continue with this by tuning the parameter

# %% [markdown]
# HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={
            'max_depth':[2,3,5],
            'min_samples_split':[1,2,3],
            'max_features':['auto', 'sqrt', 'log2']
    
}

# %%
gridsearch=GridSearchCV(rfc,
                        parameters,
                        n_jobs=-1,
                        scoring='accuracy',
                        cv=5
)

# %%
gridsearch.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [1, 2, 3]},
#              scoring='accuracy')

# %%
gridsearch.best_params_
# Out:
# {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2}

# %%
rfc=RandomForestClassifier(max_depth=5, max_features='log2', min_samples_split=2)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features='log2')

# %%
y_pred=rfc.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.9049357093442114

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 1275,  3836],
#        [  149, 36659]], dtype=int64)

# %%
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.90      0.25      0.39      5111\n           1       0.91      1.00      0.95     36808\n\n    accuracy                           0.90     41919\n   macro avg       0.90      0.62      0.67     41919\nweighted avg       0.90      0.90      0.88     41919\n'

# %% [markdown]
# ROC AUC CURVE

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
fpr, tpr, thresholds= roc_curve(y_test, y_pred)
print(' fpr is ', fpr)
print(' tpr is ', tpr)
print(' thresholds is ', thresholds)
# Out:
#  fpr is  [0.         0.75053806 1.        ]
#  tpr is  [0.         0.99595197 1.        ]
#  thresholds is  [2 1 0]

# %%
plt.plot([0,1], [0,1], 'k--')
plt.plot(fpr, tpr)
plt.title(' The random forest regressor model')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.show()

auc_score=roc_auc_score(y_test, y_pred)
print(' roc auc score of random forest classifier is ', auc_score)
# Out:
#  roc auc score of random forest classifier is  0.6227069558942955

# %% [markdown]
# SAVING THE MODEL

# %%
#import joblib
#joblib.dump(rfc.predict, 'micro-credit-defaulter.pkl')
